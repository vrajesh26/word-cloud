# %%
from selenium import webdriver

caps = webdriver.DesiredCapabilities.FIREFOX
caps["marionette"] = False

driver = webdriver.Firefox(capabilities=caps)
driver.get("https://mmb.moneycontrol.com/forum-topics/stocks/pc-jeweller-509524.html")

# %%
driver.find_element_by_xpath('/html/body/section[2]/section[5]/section/div[2]/div/div[2]/div[2]/div/ul/li[1]/div/div[2]/div/p[2]/a[1]').click()

# %%
from bs4 import BeautifulSoup
import urllib as ul

# %%
url="https://mmb.moneycontrol.com/forum-topics/stocks/pc-jeweller/thread-message-68808791-70608815.html"

# %%
doc1=ul.request.urlopen(url).read()

# %%
doc1
# Out:
# b'<!doctype html>\r\n<html>\r\n<head>\r\n<meta charset="utf-8">\r\n<title>PC Jeweller Stock Discussion Forum Online India, Can i buy PC Jeweller, Should i buy PC Jeweller, Do i buy PC Jeweller? - Moneycontrol</title>\r\n<meta name="description" content="Browse PC Jeweller stock discussion, ideas, questions and answers online at Moneycontrol.com.">\r\n<meta name="keywords" content="PC Jeweller, Can I buy PC Jeweller, Should I buy PC Jeweller, Do I buy PC Jeweller? - Moneycontrol">\r\n\r\n\r\n<script type="application/ld+json">\r\n{\r\n    "@context": "https://schema.org",\r\n    "@type": "WebPage",\r\n    "name": "PC Jeweller Stock Discussion Forum Online India, Can i buy PC Jeweller, Should i buy PC Jeweller, Do i buy PC Jeweller? - Moneycontrol",\r\n    "description": "Browse PC Jeweller stock discussion, ideas, questions and answers online at Moneycontrol.com.",\r\n    "url" : "https://mmb.moneycontrol.com/forum-topics/stocks/pc-jeweller-509524.html",\r\n    "publisher": {\r\n     
# ...

# %%
bsobj=BeautifulSoup(doc1,'lxml')

# %%
bsobj
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Techwalk. I don`t see any 400 level investor on my list. 280 Rs high buy price on my list. Only 68 i..</title>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org",
#     "@type": "WebPage",
#     "name": "Techwalk. I don`t see any 400 level investor on my list. 280 Rs high buy price on my list. Only 68 i..",
#     "description": "",
#     "url" : "https://mmb.moneycontrol.com/forum-topics/stocks/pc-jeweller/thread-message-68808791-70608815.html",
#     "publisher": {
#         "@type": "Organization",
#         "name": "MoneyControl",
#         "url" : "https://www.moneycontrol.com/",
#         "logo" : {
#         	"@type": "ImageObject",
#             "contentUrl": "https://img-d02.moneycontrol.co.in/images/common/header/logo.png?v=0.1"
#         }
#     },
#
# 	"breadcrumb":{
#       "@context": "https://schema.org",
#       "@type": "BreadcrumbList",
#       "itemListElement":[{
# ...

# %%
bsobj.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Techwalk. I don`t see any 400 level investor on my list. 280 Rs high buy price on my list. Only 68 i..\n  </title>\n  <script type="application/ld+json">\n   {\r\n    "@context": "https://schema.org",\r\n    "@type": "WebPage",\r\n    "name": "Techwalk. I don`t see any 400 level investor on my list. 280 Rs high buy price on my list. Only 68 i..",\r\n    "description": "",\r\n    "url" : "https://mmb.moneycontrol.com/forum-topics/stocks/pc-jeweller/thread-message-68808791-70608815.html",\r\n    "publisher": {\r\n        "@type": "Organization",\r\n        "name": "MoneyControl",\r\n        "url" : "https://www.moneycontrol.com/",\r\n        "logo" : {\r\n        \t"@type": "ImageObject",\r\n            "contentUrl": "https://img-d02.moneycontrol.co.in/images/common/header/logo.png?v=0.1"\r\n        }\r\n    },\r\n    \r\n\t"breadcrumb":{\r\n      "@context": "https://schema.org",\r\n      "@type": "BreadcrumbL
# ...

# %%
classes=bsobj.find_all('span')

# %%
classes
# Out:
# [<span></span>,
#  <span class="arwssUp"></span>,
#  <span class="divider"></span>,
#  <span class="divider"></span>,
#  <span class="arwssUp"></span>,
#  <span class="divider"></span>,
#  <span class="divider"></span>,
#  <span class="arwssUpLft"></span>,
#  <span id="verifiedtext" style="color:#ff5a5a"> (Unverified)</span>,
#  <span class="divider"></span>,
#  <span>&amp; </span>,
#  <span class="team2-block">
#   												SL 													<span> 203 (68.0 ov) </span>
#  </span>,
#  <span> 203 (68.0 ov) </span>,
#  <span class="ic-search"></span>,
#  <span><b>Auri</b>ferous</span>,
#  <span class="ic_seemore"></span>,
#  <span class="mmnRadio"></span>,
#  <span class="mmnRadio"></span>,
#  <span class="ic-search"></span>,
#  <span class="catDdl_Arrow"></span>,
#  <span>Auriferous</span>,
#  <span>Farma</span>,
#  <span>Solar</span>,
#  <span>More »</span>,
#  <span class="ic_marw"></span>,
#  <span class="ic_marw"></span>,
#  <span class=" platinum " style="width:30%;"></span>,
# ...

# %%
classes[2]
# Out:
# <span class="divider"></span>

# %%
price_box = bsobj.find(‘span’, attrs={‘class’:’more’})
# Out:
#   File "<ipython-input-50-33b4a974e071>", line 1
#     price_box = bsobj.find(‘span’, attrs={‘class’:’more’})
#                                 ^
# SyntaxError: invalid character in identifier

# %%
classes
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get('https://mmb.moneycontrol.com/forum-topics/stocks/tata-motors/thread-message-68377885-70177885.html')
soup = BeautifulSoup(page.text, 'html.parser')

# %%
x = soup.find(class_='clearfix follow_mainlist')

# %%
x
# Out:
# <ul class="clearfix follow_mainlist" id="msg_wraper">
# <h1 class="org15_ebop brdrh PA15"> Replies <span class="blu16_head">(11)</span></h1>
# <li id="m70609943">
# <div class="clearfix">
# <div class="FL wd150 TAC">
# <div class="meber_bar newmember"><a href="/vicky6969-user-profile-76696b617370616e646974613834.html" title="Vicky6969"><span class="icn_bar"></span> <img alt="Vicky6969" height="70" src="https://img-d02.moneycontrol.co.in/images/messageboard/home/img.jpg" title="Vicky6969" width="70"/></a></div>
# <div class="boardrPP">
# <p class="anch_pb7"><a class="txtnm14" href="/vicky6969-user-profile-76696b617370616e646974613834.html" title="Vicky6969">Vicky6969</a></p>
# <div class="boarder_ppBx">
# <div class="clearfix anchbrddas">
# <div class="FL w200"> <img class="boardpic FL" height="70" src="https://img-d02.moneycontrol.co.in/images/messageboard/home/img.jpg" width="70"/>
# ...

# %%
out=x.contents

# %%
out
# Out:
# ['\n',
#  <h1 class="org15_ebop brdrh PA15"> Replies <span class="blu16_head">(11)</span></h1>,
#  '\n',
#  <li id="m70609943">
#  <div class="clearfix">
#  <div class="FL wd150 TAC">
#  <div class="meber_bar newmember"><a href="/vicky6969-user-profile-76696b617370616e646974613834.html" title="Vicky6969"><span class="icn_bar"></span> <img alt="Vicky6969" height="70" src="https://img-d02.moneycontrol.co.in/images/messageboard/home/img.jpg" title="Vicky6969" width="70"/></a></div>
#  <div class="boardrPP">
#  <p class="anch_pb7"><a class="txtnm14" href="/vicky6969-user-profile-76696b617370616e646974613834.html" title="Vicky6969">Vicky6969</a></p>
#  <div class="boarder_ppBx">
#  <div class="clearfix anchbrddas">
#  <div class="FL w200"> <img class="boardpic FL" height="70" src="https://img-d02.moneycontrol.co.in/images/messageboard/home/img.jpg" width="70"/>
# ...

# %%
out=x.findAll(class_='txt16gry')

# %%
out
# Out:
# [<p class="txt16gry">Tata motors will reach Rs350 in 1 year time. Purchase now</p>,
#  <p class="txt16gry">total bearish charts tata motors,keep 150 approx exit trigger govindji !!</p>,
#  <p class="txt16gry">yes wait for the stock to reach around 11 rs</p>,
#  <p class="txt16gry">Buy gtl infra at 1.25  Big blast in coming sessions. Tomorrow out of ASM LISM. frm 30 oct..</p>,
#  <p class="txt16gry">sir can we re look shakti pump again at 378 now.</p>,
#  <p class="txt16gry">sir look at navkar corp how can u forget your favourite stocks</p>,
#  <p class="txt16gry">Bug ruchi soya at 5.15. Anytime big annoucement on Adani wilmar deal. be ready</p>,
#  <p class="txt16gry">No you should not invest ,,,wait for 140 levels.</p>,
#  <p class="txt16gry">Closing 185 plus plus dnt miss in end just see power</p>,
#  <p class="txt16gry">Can one invest in tata motors now?</p>]

# %%
out1=[th.text.rstrip() for th in out]

# %%
out1
# Out:
# ['Tata motors will reach Rs350 in 1 year time. Purchase now',
#  'total bearish charts tata motors,keep 150 approx exit trigger govindji !!',
#  'yes wait for the stock to reach around 11 rs',
#  'Buy gtl infra at 1.25  Big blast in coming sessions. Tomorrow out of ASM LISM. frm 30 oct..',
#  'sir can we re look shakti pump again at 378 now.',
#  'sir look at navkar corp how can u forget your favourite stocks',
#  'Bug ruchi soya at 5.15. Anytime big annoucement on Adani wilmar deal. be ready',
#  'No you should not invest ,,,wait for 140 levels.',
#  'Closing 185 plus plus dnt miss in end just see power',
#  'Can one invest in tata motors now?']

# %%
from selenium import webdriver

caps = webdriver.DesiredCapabilities.FIREFOX
caps["marionette"] = False

driver = webdriver.Firefox(capabilities=caps)
driver.get("https://mmb.moneycontrol.com/forum-topics/stocks/tata-motors-1605.html")

# %%
cont=driver.find_elements_by_class_name('txt16gry')

# %%
text=[q.text.strip() for q in cont]

# %%
text
# Out:
# ['',
#  'Tata Motors down 2% after JLR sales in October fall 4.6%. Have an opinion on this news? Post your comment here. 3 comments',
#  'Don`t try to catch falling knife. Target 120 in 6 months.',
#  'Don`t try to catch falling knife. Target 120 in 6 months.',
#  'sell target is 185.9 shorting trade today sell at 189',
#  'sell target is 185.9 shorting trade today sell at 189',
#  'Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50',
#  'Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50',
#  'Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry | 5',
#  'Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry',
#  'Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target | 5',
#  'Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target',
# ...

# %%
out=[i.split(',') for i in text]

# %%
out
# Out:
# [[''],
#  ['Tata Motors down 2% after JLR sales in October fall 4.6%. Have an opinion on this news? Post your comment here. 3 comments'],
#  ['Don`t try to catch falling knife. Target 120 in 6 months.'],
#  ['Don`t try to catch falling knife. Target 120 in 6 months.'],
#  ['sell target is 185.9 shorting trade today sell at 189'],
#  ['sell target is 185.9 shorting trade today sell at 189'],
#  ['Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50'],
#  ['Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50'],
#  ['Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry | 5'],
#  ['Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry'],
#  ['Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target | 5'],
#  ['Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target'],
#  ['@Dipak da',
#   ' I know today is selling day for tamo',
# ...

# %%
b = list()

# %%
for sublist in out:
    if sublist not in b:
        b.append(sublist)

# %%
b
# Out:
# [[''],
#  ['Tata Motors down 2% after JLR sales in October fall 4.6%. Have an opinion on this news? Post your comment here. 3 comments'],
#  ['Don`t try to catch falling knife. Target 120 in 6 months.'],
#  ['sell target is 185.9 shorting trade today sell at 189'],
#  ['Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50'],
#  ['Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry | 5'],
#  ['Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry'],
#  ['Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target | 5'],
#  ['Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target'],
#  ['@Dipak da',
#   ' I know today is selling day for tamo',
#   ' it is favour of sellers(naresh).....but I am always loves tp take challenge and hope it will easily cross my 1st tgt. 192.....Jai Ma.'],
#  ['TATA MOTORS',
# ...

# %% [markdown]
# result = []

# %% [markdown]
# [result.extend(el) for el in b]

# %%
output=[item for sublist in b for item in sublist]

# %%
output=output[1:len(output)]

# %%
output
# Out:
# ['Tata Motors down 2% after JLR sales in October fall 4.6%. Have an opinion on this news? Post your comment here. 3 comments',
#  'Don`t try to catch falling knife. Target 120 in 6 months.',
#  'sell target is 185.9 shorting trade today sell at 189',
#  'Sell Tatamotors cmp 189 Sl 196 tgt 180-175 Try 180 Put cmp 3.90-3.50',
#  'Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry | 5',
#  'Hello Friends ... Day High 200 Plus .... Super Profits In Tata Motors Latest Entry',
#  'Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target | 5',
#  'Hello Friends ... Three Days Time Frame ... Buy Tata Motors For 188 Target',
#  '@Dipak da',
#  ' I know today is selling day for tamo',
#  ' it is favour of sellers(naresh).....but I am always loves tp take challenge and hope it will easily cross my 1st tgt. 192.....Jai Ma.',
#  'TATA MOTORS',
# ...

# %%
x=[i.lower() for i in output]

# %%
x
# Out:
# ['tata motors down 2% after jlr sales in october fall 4.6%. have an opinion on this news? post your comment here. 3 comments',
#  'don`t try to catch falling knife. target 120 in 6 months.',
#  'sell target is 185.9 shorting trade today sell at 189',
#  'sell tatamotors cmp 189 sl 196 tgt 180-175 try 180 put cmp 3.90-3.50',
#  'hello friends ... day high 200 plus .... super profits in tata motors latest entry | 5',
#  'hello friends ... day high 200 plus .... super profits in tata motors latest entry',
#  'hello friends ... three days time frame ... buy tata motors for 188 target | 5',
#  'hello friends ... three days time frame ... buy tata motors for 188 target',
#  '@dipak da',
#  ' i know today is selling day for tamo',
#  ' it is favour of sellers(naresh).....but i am always loves tp take challenge and hope it will easily cross my 1st tgt. 192.....jai ma.',
#  'tata motors',
# ...

# %%
from gensim.parsing.preprocessing import remove_stopwords
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import gensim

# %%
text=[gensim.parsing.remove_stopwords(t) for t in x]

# %%
text
# Out:
# ['tata motors 2% jlr sales october fall 4.6%. opinion news? post comment here. 3 comments',
#  'don`t try catch falling knife. target 120 6 months.',
#  'sell target 185.9 shorting trade today sell 189',
#  'sell tatamotors cmp 189 sl 196 tgt 180-175 try 180 cmp 3.90-3.50',
#  'hello friends ... day high 200 plus .... super profits tata motors latest entry | 5',
#  'hello friends ... day high 200 plus .... super profits tata motors latest entry',
#  'hello friends ... days time frame ... buy tata motors 188 target | 5',
#  'hello friends ... days time frame ... buy tata motors 188 target',
#  '@dipak da',
#  'know today selling day tamo',
#  'favour sellers(naresh).....but loves tp challenge hope easily cross 1st tgt. 192.....jai ma.',
#  'tata motors',
#  'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra taken enormous initiatives stream line tamo indian interntional l...',
#  'tata motors',
# ...

# %%
#text=[re.sub("[^\w]",' ',t) for t in text]

# %%
import re

# %%
text=[re.sub('[0-9]','',t) for t in text]

# %%
text
# Out:
# ['tata motors % jlr sales october fall .%. opinion news? post comment here.  comments',
#  'don`t try catch falling knife. target   months.',
#  'sell target . shorting trade today sell ',
#  'sell tatamotors cmp  sl  tgt - try  cmp .-.',
#  'hello friends ... day high  plus .... super profits tata motors latest entry | ',
#  'hello friends ... day high  plus .... super profits tata motors latest entry',
#  'hello friends ... days time frame ... buy tata motors  target | ',
#  'hello friends ... days time frame ... buy tata motors  target',
#  '@dipak da',
#  'know today selling day tamo',
#  'favour sellers(naresh).....but loves tp challenge hope easily cross st tgt. .....jai ma.',
#  'tata motors',
#  'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra taken enormous initiatives stream line tamo indian interntional l...',
#  'tata motors',
# ...

# %%
text=[re.sub('\ |\?|\.|\!|\/|\;|\:|\-|\`|\*|\!|\#|\$|\%|\(|\)|\+|\.|\@|\=|\_|\|', ' ', sentence) for sentence in text]

# %%
str(text)
# Out:
# '[\'tata motors   jlr sales october fall     opinion news  post comment here   comments\', \'don t try catch falling knife  target   months \', \'sell target   shorting trade today sell \', \'sell tatamotors cmp  sl  tgt   try  cmp    \', \'hello friends     day high  plus      super profits tata motors latest entry   \', \'hello friends     day high  plus      super profits tata motors latest entry\', \'hello friends     days time frame     buy tata motors  target   \', \'hello friends     days time frame     buy tata motors  target\', \' dipak da\', \'know today selling day tamo\', \'favour sellers naresh      but loves tp challenge hope easily cross st tgt       jai ma \', \'tata motors\', \'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra taken enormous initiatives stream line tamo indian interntional l   \', \'tata motors\', \'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra
# ...

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
text=[remove_emoji(t) for t in text ]

# %%
def normalize_space(s):
    return ' '.join(s.split())

# %%
text=[normalize_space(i) for i in text]

# %%
text
# Out:
# ['tata motors jlr sales october fall opinion news post comment here comments',
#  'don t try catch falling knife target months',
#  'sell target shorting trade today sell',
#  'sell tatamotors cmp sl tgt try cmp',
#  'hello friends day high plus super profits tata motors latest entry',
#  'hello friends day high plus super profits tata motors latest entry',
#  'hello friends days time frame buy tata motors target',
#  'hello friends days time frame buy tata motors target',
#  'dipak da',
#  'know today selling day tamo',
#  'favour sellers naresh but loves tp challenge hope easily cross st tgt jai ma',
#  'tata motors',
#  'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra taken enormous initiatives stream line tamo indian interntional l',
#  'tata motors',
#  'tata sons wanted enhance stake virus mistry intentionally kept company bad light ratan tata t chandra taken enormous initiatives stream line tamo indian interntional l',
# ...

# %%
x=[i.split(" ") for i in text]

# %%
x
# Out:
# [['tata',
#   'motors',
#   'jlr',
#   'sales',
#   'october',
#   'fall',
#   'opinion',
#   'news',
#   'post',
#   'comment',
#   'here',
#   'comments'],
#  ['don', 't', 'try', 'catch', 'falling', 'knife', 'target', 'months'],
#  ['sell', 'target', 'shorting', 'trade', 'today', 'sell'],
#  ['sell', 'tatamotors', 'cmp', 'sl', 'tgt', 'try', 'cmp'],
#  ['hello',
#   'friends',
#   'day',
#   'high',
#   'plus',
#   'super',
#   'profits',
#   'tata',
#   'motors',
#   'latest',
#   'entry'],
#  ['hello',
#   'friends',
#   'day',
#   'high',
#   'plus',
#   'super',
#   'profits',
#   'tata',
#   'motors',
#   'latest',
#   'entry'],
#  ['hello',
#   'friends',
#   'days',
#   'time',
#   'frame',
#   'buy',
#   'tata',
#   'motors',
#   'target'],
#  ['hello',
#   'friends',
#   'days',
#   'time',
#   'frame',
#   'buy',
#   'tata',
#   'motors',
#   'target'],
#  ['dipak', 'da'],
#  ['know', 'today', 'selling', 'day', 'tamo'],
#  ['favour',
#   'sellers',
#   'naresh',
# ...

# %%
v=list()

# %%
for i in x:
    for j in i:
        if j not in words:
            i.remove(j)

# %%
i
# Out:
# ['buy', 'share', 'sub', 'chore', 'hay']

# %%
[i for i in x[0] if i in words]
# Out:
# ['c', 'a', 'b', 'a', 'l', 'i', 's', 't', 'i', 'c']

# %%
import nltk

# %%
words=set(nltk.corpus.words.words())

# %%
words
# Out:
# {'proctorrhagia',
#  'revelationer',
#  'talcer',
#  'pargeboard',
#  'trephone',
#  'opalescent',
#  'adjuration',
#  'reduce',
#  'unimperialistic',
#  'pathogenetic',
#  'quartzose',
#  'sneezeproof',
#  'catchingness',
#  'wauve',
#  'hypnesthetic',
#  'faineancy',
#  'brassware',
#  'illegitimateness',
#  'spotted',
#  'collatitious',
#  'commensurate',
#  'roun',
#  'fringillaceous',
#  'narrowish',
#  'Vedantic',
#  'vikinglike',
#  'isoseismical',
#  'borghalpenny',
#  'lichenographer',
#  'nesquehonite',
#  'allan',
#  'Colubriformes',
#  'fredricite',
#  'overbearingly',
#  'triternate',
#  'chanco',
#  'soberly',
#  'intensifier',
#  'unrelieved',
#  'cymotrichous',
#  'straightly',
#  'staphylodermatitis',
#  'tracheostenosis',
#  'supertax',
#  'Persianize',
#  'capulet',
#  'mains',
#  'bacchian',
#  'groundlessly',
#  'bovarysm',
#  'uncoddled',
#  'unostentatiously',
#  'julole',
#  'assuasive',
#  'rath',
#  'shipworm',
#  'cosmographer',
#  'surrenal',
# ...

# %%
len(words)
# Out:
# 235892

# %%
word_tok=" ".join(text)

# %%
dic=[]

# %%
dic_words=nltk.word_tokenize(word_tok)

# %%
final_words=[i for i in dic_words if i in words]

# %%
final_words
# Out:
# ['fall',
#  'opinion',
#  'news',
#  'post',
#  'comment',
#  'here',
#  'don',
#  't',
#  'try',
#  'catch',
#  'falling',
#  'knife',
#  'target',
#  'sell',
#  'target',
#  'trade',
#  'today',
#  'sell',
#  'sell',
#  'try',
#  'hello',
#  'day',
#  'high',
#  'plus',
#  'super',
#  'latest',
#  'entry',
#  'hello',
#  'day',
#  'high',
#  'plus',
#  'super',
#  'latest',
#  'entry',
#  'hello',
#  'days',
#  'time',
#  'frame',
#  'buy',
#  'target',
#  'hello',
#  'days',
#  'time',
#  'frame',
#  'buy',
#  'target',
#  'da',
#  'know',
#  'today',
#  'selling',
#  'day',
#  'but',
#  'challenge',
#  'hope',
#  'easily',
#  'cross',
#  'st',
#  'ma',
#  'sons',
#  'enhance',
#  'stake',
#  'virus',
#  'mistry',
#  'intentionally',
#  'kept',
#  'company',
#  'bad',
#  'light',
#  't',
#  'taken',
#  'enormous',
#  'stream',
#  'line',
#  'l',
#  'sons',
#  'enhance',
#  'stake',
#  'virus',
#  'mistry',
#  'intentionally',
#  'kept',
#  'company',
#  'bad',
#  'light',
#  't',
# ...

# %%
import re

# %%
def remove_characters_before_tokenization(sentence,keep_apostrophes=False):
    sentence = sentence.strip() 
    if keep_apostrophes: 
            PATTERN = r'[!|"|#|$|%|&|(|)|*|+|,|-|.|/|:|;|<|=|>|?|@|[|\|]|^|_|`|{|}|~]' 
            filtered_sentence = re.sub(PATTERN, r'', sentence) 
    else: 
        PATTERN = r'[^a-zA-Z0-9 ]'
        filtered_sentence = re.sub(PATTERN, r'', sentence) 
    return filtered_sentence

# %%
text = [remove_characters_before_tokenization(t,keep_apostrophes=True) for t in text ]

# %%
text
# Out:
# ['tata motors moving  its stuck - only',
#  'buy closing time buy low price',
#  'buy tata motors company seriously listening grievances shareholders erosion capital  repeated request demerge valued non synergied subsidiaries having huge hidden value  making mind reward    b',
#  'buy tata motors company seriously listening grievances shareholders erosion capital  repeated request demerge valued non synergied subsidiaries having huge hidden value  making mind reward    b',
#  'folowers sell hear  tuch buy  today u want profit 😎😎😎😎😎😎😎😎',
#  'buy tata motors - sl  target  positionally ',
#  'holding strong day closing spike expected today',
#  'accumulation going stock slowly gradually moving north sideonly buy counter',
#  'loss mag quarter followed news deitely sell sp places tata motors long-term rag creditwatch negative implications read at economictimesdiatimesarticleshowcmsutmsourceco',
# ...

# %%
[re.sub(r'[^\w]'," ",t) for t in text]
# Out:
# ['tata motors moving  its stuck   only',
#  'buy closing time buy low price',
#  'buy tata motors company seriously listening grievances shareholders erosion capital  repeated request demerge valued non synergied subsidiaries having huge hidden value  making mind reward    b',
#  'buy tata motors company seriously listening grievances shareholders erosion capital  repeated request demerge valued non synergied subsidiaries having huge hidden value  making mind reward    b',
#  'folowers sell hear  tuch buy  today u want profit         ',
#  'buy tata motors   sl  target  positionally ',
#  'holding strong day closing spike expected today',
#  'accumulation going stock slowly gradually moving north sideonly buy counter',
#  'loss mag quarter followed news deitely sell sp places tata motors long term rag creditwatch negative implications read at economictimesdiatimesarticleshowcmsutmsourceco',
# ...

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
from nltk.stem.porter import PorterStemmer
porter = PorterStemmer()
[porter.stem(word) for word in tokens]

# %%
final=''.join(output)

# %%
from wordcloud import STOPWORDS,WordCloud

# %%
STOPWORDS
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
# ...

# %%
wc=WordCloud(max_words=20,stopwords=STOPWORDS,height=800,width=1000)

# %%
wc.generate(final)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(wc)
